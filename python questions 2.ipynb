# %%
Program 1: Road Tax Calculation

python
Copy code
cost_price = float(input("Enter the cost price of the bike (in Rs): "))

if cost_price > 100000:
    road_tax = cost_price * 0.15
elif cost_price > 50000:
    road_tax = cost_price * 0.10
else:
    road_tax = cost_price * 0.05

print(f"Road tax to be paid: {road_tax:.2f} Rs")
Program 2: Monuments in Different Cities

python
Copy code
city = input("Enter a city (Delhi, Agra, or Jaipur): ")

if city.lower() == "delhi":
    monument = "Red Fort"
elif city.lower() == "agra":
    monument = "Taj Mahal"
elif city.lower() == "jaipur":
    monument = "Jal Mahal"
else:
    monument = "Unknown"

if monument != "Unknown":
    print(f"The monument in {city} is {monument}.")
else:
    print("Monument information not available for this city.")
Program 3: Divisions by 3

python
Copy code
number = int(input("Enter a number: "))
count = 0

while number > 10:
    number /= 3
    count += 1

print(f"The number can be divided by 3 {count} times before it is less than or equal to 10.")
Program 4: Using while Loop

The while loop in Python is used when you want to repeatedly execute a block of code as long as a certain condition is true. It's particularly useful when you don't know how many times the loop needs to run in advance.

Example:

python
Copy code
total = 0
count = 1

while count <= 5:
    num = int(input(f"Enter number {count}: "))
    total += num
    count += 1

average = total / 5
print(f"Average of the numbers is: {average}")
Program 5: Nested while Loop Patterns

python
Copy code
# Pattern 1
n = 5
i = 1

while i <= n:
    print("*" * i)
    i += 1

# Pattern 2
n = 4
i = n

while i >= 1:
    print(" " * (n - i) + "*" * i)
    i -= 1

# Pattern 3
n = 5
i = n

while i >= 1:
    print(" " * (n - i) + "*" * (2 * i - 1))
    i -= 1
Program 6: Reverse while Loop

python
Copy code
num = 10

while num >= 1:
    print(num)
    num -= 1
Program 7: Grade Calculation

python
Copy code
percentage = float(input("Enter the percentage: "))

if percentage > 90:
    grade = "A"
elif percentage > 80:
    grade = "B"
elif percentage >= 60:
    grade = "C"
else:
    grade = "D"

print(f"The grade based on the percentage is: {grade}")
